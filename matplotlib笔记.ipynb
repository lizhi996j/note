# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## Runboo 教程

# %% [markdown]
# ### 绘制线形图
# matplotlib.pyplot.plot(x, y, format_string, **kwargs)函数：
# - format_string：线条的样式、颜色和标记.
#     - 颜色字符：'b' 蓝色，'m' 洋红色，'g' 绿色，'y' 黄色，'r' 红色，'k' 黑色，'w' 白色，'c' 青绿色，'#008000' RGB 颜色符串。多条曲线不指定颜色时，会自动选择不同颜色。
#     - 线型参数：'‐' 实线，'‐‐' 破折线，'‐.' 点划线，':' 虚线。
#     - 标记字符：'.' 点标记，',' 像素标记(极小点)，'o' 实心圈标记，'v' 倒三角标记，'^' 上三角标记，'>' 右三角标记，'<' 左三角标记...等等
# - 用于设置更多的绘图参数，比如标签、标题、线宽、颜色等

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 100])

plt.plot(xpoints, ypoints)
plt.show()
plt.plot(xpoints,ypoints,'y:.')
plt.show()

# %% [markdown]
# #### 定义标记的内部颜色，边框颜色和大小
# - markersize，简写为 ms：定义标记的大小。
# - markerfacecolor，简写为 mfc：定义标记内部的颜色。
# - markeredgecolor，简写为 mec：定义标记边框的颜色。

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([6,2,13,10])

plt.plot(y,marker="o",ms=20,mfc="b",mec="r")

# %% [markdown]
# 自定义内部和边框颜色
# 颜色代码（Hex Color Code）是一种用六位十六进制数字来表示 RGB 颜色的方法，格式为 #RRGGBB，其中：
#
# RR：表示红色通道（Red）的强度，范围从 00（最小，十进制 0）到 FF（最大，十进制 255）；
#
# GG：表示绿色通道（Green）的强度，同样从 00 到 FF；
#
# BB：表示蓝色通道（Blue）的强度，同样从 00 到 FF。
#
# 举例来说，#4CAF50 可以拆解为：
#
# 红色 4C → 十六进制 4C = 十进制 76
#
# 绿色 AF → 十六进制 AF = 十进制 175
#
# 蓝色 50 → 十六进制 50 = 十进制 80

# %%
plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4C0F50')

# %% [markdown]
# #### 定义线的类型，颜色，宽度以及多条线

# %% [markdown]
# 线的类型：linestyle参数
#
#  | 类型 | 简写 | 说明 |
#  |------|------|------|
#  | 'solid' (默认) | '-' | 实线 |
#  | 'dotted' | ':' | 点虚线 |
#  | 'dashed' | '--' | 破折线 |
#  | 'dashdot' | '-.' | 点划线 |
#  | 'None' | '' 或 ' ' | 不画线 |

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([6, 2, 13, 10])

plt.plot(ypoints, ls = '-.')
plt.show()

# %% [markdown]
# 线的颜色： color或简写为c参数
# 线的粗细：linewidth或简写为lw参数

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([6, 2, 13, 10])

plt.plot(ypoints, linewidth = '12.5')
plt.show()

# %% [markdown]
# #### 绘制多条线
# ##### 如果x的范围不同会取并集
# 当你用 plt.xlim(a, b) 手动限制横轴范围为 [a, b] 时，任何落在此区间之外的数据点都不会被绘制到图上——它们被“剪裁”掉了。

# %%
import matplotlib.pyplot as plt

# 第一条线的 x1 范围是 [0,1,2,3]
x1 = [0, 1, 2, 3]
y1 = [1, 4, 9, 16]

# 第二条线的 x2 范围是 [1,3,5]
x2 = [1, 3, 5]
y2 = [2, 6, 3]

plt.plot(x1, y1, label='y1')
plt.plot(x2, y2, label='y2')
plt.legend()
plt.show()

# %% [markdown]
# ##### 绘制x轴不同但共享y轴的图
# 生成一个ax2, ax2与ax1共享y轴但独立x轴

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twiny()   # 生成一个共享 y 轴但独立 x 轴的坐标系

ax1.plot(x1, y1, color='blue', label='y1 on ax1')
ax2.plot(x2, y2, color='red',  label='y2 on ax2')

# 分别设置两个坐标系的 x 轴标签
ax1.set_xlabel('x1 in [0,3]')
ax2.set_xlabel('x2 in [1,5]')

# 可以单独设置它们的 xlim
ax1.set_xlim(0, 3)
ax2.set_xlim(1, 5)

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### 绘制散点图
# - matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, *, edgecolors=None, plotnonfinite=False, data=None, **kwargs)
#     - c : 点的颜色
#     - s : 点的大小
#     - cmap : colormap
# - plt.colorbar() : 添加颜色条; 有颜色条时可通过color设置颜色强度；颜色条的种类上网查；

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %% [markdown]
# ### 热力图，地图，等高线图等
# 有三个函数可以用：
# - imshow():
# - pcolormesh(): pseudocolor mesh
# - contour()/contourf(): 后者是有颜色填充的等高线

# %% [markdown]
# #### imshow()
# - 当输入二维数据时，会自动把数据映射到color map，默认cmap参数是viridis;
# - 如果是三维RBG或思维RBGA会忽略cmap参数及其相关参数;

# %%
import numpy as np
import matplotlib.pyplot as plt
data1 = np.random.rand(10,10)
data2 = np.random.rand(10,10,3) # RGB应该有范围，但这里没管；
fig, ax = plt.subplots()
ax.imshow(data1)
fig, ax = plt.subplots()
ax.imshow(data2)

# %% [markdown]
# #### ax.pcolormesh：
# 与contourf不同的是：contourf会按等高线填充颜色；

# %%
X, Y = np.meshgrid(np.linspace(-3, 3, 128), np.linspace(-3, 3, 128))
Z = (1 - X/2 + X**5 + Y**3) * np.exp(-X**2 - Y**2)

fig, axs = plt.subplots(layout='constrained')
pc = axs.pcolormesh(X, Y, Z, vmin=-1, vmax=1, cmap='RdBu_r')

# %% [markdown]
# #### 等高线图
# - 注意：规则二维网络对contour方法很重要，如果点不规则，使用tricontour方法;
# - 下面的例子用tricountour方法绘制球心在(1,1,0)的球的等高线；难点在于生成的点是正方形取样，要去掉落在外面的点; 还可以使用mask
# - 规则二维网格（rectilinear grid）：点坐标是按两条独立坐标轴的笛卡尔积生成的，即点集为 {(x_j, y_i)}。
# 形状：X.shape == Y.shape == Z.shape == (Ny, Nx)
# 结构：X[i, j] = x[j]（每行相同），Y[i, j] = y[i]（每列相同）
# 要求：x 与 y 在各自轴上单调（可不等距）

# %%
import numpy as np
import matplotlib.pyplot as plt
x:np.ndarray = np.linspace(0,2,100)
y:np.ndarray = np.linspace(0,2,100)
X,Y = np.meshgrid(x,y)
X,Y = X.reshape(-1), Y.reshape(-1)
Z_square = (1-(X-1)**2-(Y-1)**2).reshape(-1)
index = Z_square>=0
# X,Y,Z = X[index].reshape(2,-1),Y[index].reshape(2,-1),np.sqrt(Z_square[index]).reshape(2,-1) 
X,Y,Z = X[index],Y[index],np.sqrt(Z_square[index])
plt.tricontour(X,Y,Z,levels=np.linspace(0,1,5))

# %%
import numpy as np
import matplotlib.pyplot as plt

theta = np.linspace(0, 2*np.pi, 360)
r = np.linspace(0, 1.0, 200)
T, R = np.meshgrid(theta, r)

Z = np.sqrt(1 - R**2)  # 例：单位圆盘上的函数

ax = plt.subplot(projection='polar')
cs = ax.contourf(T, R, Z, levels=np.linspace(0,1,8), cmap='viridis')
plt.colorbar(cs)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 数据
x = np.linspace(-3, 3, 400)
y = np.linspace(-3, 3, 400)
X, Y = np.meshgrid(x, y)
Z = np.sin(X) * np.cos(Y)

# 只画等高线（不填充）
cs = plt.contour(X, Y, Z, levels=np.linspace(-1, 1, 11), cmap='viridis')
# plt.clabel(cs, fmt="%.2f")  # 在线上标注数值
# plt.colorbar(cs, label='Z')  # 每条线对应的值
# plt.axis('equal')
plt.show()

# %% [markdown]
# ### 关于图中的坐标
# 有三种坐标：
# - 数据坐标：每个数据点在图中的位置，由x和y坐标决定。
# - 轴坐标：每个轴在图中的位置，由轴的起点和终点决定。
# - 图坐标：整个图在图中的位置，由图的起点和终点决定。
#
# | 坐标类型 | 函数/方法 | 坐标范围 | 典型用途 |
# |----------|-----------|----------|----------|
# | 数据坐标 | plt.text / ax.text | 按数据值 | 在数据点处标注 |
# | 轴坐标 | ax.text(..., transform=ax.transAxes) | [0,1] | 在子图固定位置放置文字、图例等 |
# | 画布坐标 | fig.text | [0,1] | 全局标题、水印、注释框 |

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2]
y = [1, 4, 9]
plt.plot(x, y)

# 在数据坐标 (1, 4) 处放文字
plt.text(1, 4, "这里是 (1,4)", fontsize=12)

plt.show()
# Out:
# a:\program files\anaconda3\envs\pytorch\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 36825 (\N{CJK UNIFIED IDEOGRAPH-8FD9}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# a:\program files\anaconda3\envs\pytorch\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 37324 (\N{CJK UNIFIED IDEOGRAPH-91CC}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# a:\program files\anaconda3\envs\pytorch\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 26159 (\N{CJK UNIFIED IDEOGRAPH-662F}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import numpy as np
import matplotlib.pyplot as plt

# 构造数据
x = np.linspace(0, 5, 100)
y = np.linspace(0, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(X) * np.cos(Y)

# 创建对比图
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# pcolormesh
pcm = axes[0].pcolormesh(X, Y, Z, cmap='viridis', shading='auto')
fig.colorbar(pcm, ax=axes[0])
axes[0].set_title('pcolormesh')
axes[0].set_xlabel('X')
axes[0].set_ylabel('Y')

# contourf
cf = axes[1].contourf(X, Y, Z, levels=20, cmap='viridis')
fig.colorbar(cf, ax=axes[1])
axes[1].set_title('contourf')
axes[1].set_xlabel('X')
axes[1].set_ylabel('Y')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 绘制多图:
# 有两种方法：
# - matplotlib.pyplot.subplot(nrows, ncols, index, **kwargs)
# - matplotlib.pyplot.subplots(nrows=1, ncols=1, *,
#                            sharex=False, sharey=False,
#                            squeeze=True, subplot_kw=None,
#                            gridspec_kw=None, **fig_kw)
# 参数解释：
#
# |参数|	类型|	说明|
# |---|---|---|
# |nrows|	int 默认 1| 子图的行数
# |ncols|	int 默认 1| 子图的列数
# |sharex|	bool or {'none','all','row','col'}| 子图是否共享 X 轴
# |sharey|	bool or {'none','all','row','col'}| 子图是否共享 Y 轴
# |squeeze|	bool 默认 True| 如果为 True，则当子图数为 1 时返回单个 Axes 对象，否则返回二维 ndarray
# |subplot_kw|	dict 可选| 传递给 add_subplot() 的关键字参数（如 projection='polar'）
# |gridspec_kw|	dict 可选| 传递给 GridSpec 构造器的参数（如 width_ratios、height_ratios）
# |fig_kw|	其它关键字参数| 传给 plt.figure() 的参数（如 figsize, dpi 等）

# %%
# 使用plt.subplot()
import numpy as np
import matplotlib.pyplot as plt
x_1 = np.linspace(0,50,10)
y_1 = x_1**2
x_2 = np.logspace(1,10,10,base=2)
y_2 = x_2**2

plt.subplot(1,2,1)
plt.plot(x_1,y_1)

plt.subplot(1,2,2)
plt.plot(x_2,y_2)

plt.show()
plt.close()

# %%
# 使用plt.subplots()
x_1 = np.linspace(0,50,10)
y_1 = x_1**2
x_2 = np.logspace(1,10,10,base=2)
y_2 = x_2**2
fig,ax = plt.subplots(1,2)
ax[0].plot(x_1,y_1)
ax[1].plot(x_2,y_2)
fig.show()

# %% [markdown]
# ### 显示轴和标题
# - 轴和标题的位置：
#     - title() 方法提供了 loc 参数来设置标题显示的位置，可以设置为: 'left', 'right', 和 'center'， 默认值为 'center'。
#
#     - xlabel() 方法提供了 loc 参数来设置 x 轴显示的位置，可以设置为: 'left', 'right', 和 'center'， 默认值为 'center'。
#
#     - ylabel() 方法提供了 loc 参数来设置 y 轴显示的位置，可以设置为: 'bottom', 'top', 和 'center'， 默认值为 'center'。

# %% [markdown]
# #### matplotlib.pyplot.title(label, fontdict=None, loc='center', pad=None, **kwargs)
# - label: 标题文本
# - fontdict:字体字典，可以设置：
#     - fontsize（字号，如 12、'large' 等）
#     - fontweight（粗细，如 'bold'、'semibold'）
#     - fontstyle（样式，如 'italic'）
#     - fontfamily（字体族，如 'serif'、'sans-serif'）
#     - color（颜色，如 'blue'、'#333333'）
# 可以如下面例子一样传递字典形式，也可以直接传递参数
# - loc: 标题位置，可选值：'center'、'left'、'right'
# - pad: 标题与图的距离，默认值为 None
# - **kwargs: 其他参数，如 backgroundcolor、bbox、rotation等 <font color='red'>关于backgroundcolor和bbox中facecolor的区别没太懂</font>

# %%
import matplotlib.pyplot as plt

# 准备数据
x = [1, 2, 3, 4]
y = [10, 20, 15, 25]

fig, ax = plt.subplots(figsize=(6, 4))
ax.plot(x, y)

# 使用 fontdict 和 loc、pad、额外 kwargs
ax.set_title(
    "Example",
    fontdict={
        'fontsize': 16,
        'fontweight': 'bold',
        'fontfamily': 'sans-serif',
        'color': '#2E86AB'
    },
    loc='left',
    pad=20,
    backgroundcolor='#000000',
    bbox={'facecolor': '#FFFFFF', 'edgecolor': '#2E86AB', 'boxstyle': 'round,pad=0.3'},
    rotation=0
)

plt.show()

# %% [markdown]
# ### 显示网格线
# matplotlib.pyplot.grid(b=None, which='both', axis='both', color='k', linestyle='-', linewidth=0.5, alpha=None)
# - alpha是透明度
# - which指示用主刻度还是副刻度来绘制网格

# %%
import matplotlib.pyplot as plt

# 示例数据
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

plt.plot(x, y)

# 设置网格线的样式
plt.grid(True, which='major', axis='both', color='b', linestyle='--', linewidth=1,alpha=1)

plt.show()

# %% [markdown]
# ### 设置刻度线
# 两种组合：
# 1. 手动设置刻度位置和标签
# - Axes.set_xticks(self, ticks, *, minor=False)
# - Axes.set_yticklabels(
#     labels,
#     *,
#     fontdict=None,
#     minor=False,
#     **kwargs
# )
# 2. 结合locator和formatter自动设置刻度位置和标签
# - Axes.xaxis.set_major_locator(locator)
#     locator的种类：
#     - AutoLocator: 自动选择最佳主刻度
#     - MaxNLocator(n): 在坐标轴范围内最多生成 n 条主刻度，刻度间距尽量“整洁”（如整数、四舍五入后的小数）
#     - MultipleLocator(base): 在坐标轴范围内，每隔 base 单位生成一个刻度
#     - IndexLocator(base, offset): 用于IndexLocator不关心数据的实际数值大小，只按“第几个点”计算位置的情况，从offset开始，每隔base个单位生成一个刻度
# - Axes.xaxis.set_major_formatter(formatter)
#     formatter的种类：
#     - FormatStrFormatter(fmt): 	按 Python 格式化字符串（如 '%0.2f'、'%d%%'）来渲染标签
#     - PercentFormatter(xmax=1.0)	将刻度值按百分比显示（0–1 映射为 0%–100%）
#     - FuncFormatter(func): 使用自定义函数来渲染标签
#     - FixedFormatter(values): 使用固定值列表来渲染标签
#     - DateFormatter(fmt): 使用日期格式化字符串来渲染标签
# 3. ax.tick_params(axis='both', which='major', **kwargs) 是从“样式/显示属性”层面，统一控制刻度线（ticks）和刻度标签（tick labels）的外观（线长、线宽、方向、颜色、字体大小等）。
# 4. 获得tick的location和label
#     tick_locations = ax.get_xticks()
#     tick_labels = ax.get_xticklabels()  # 返回的是text对象
#     print(tick_locations)
#     print(tick_labels)

# %% [markdown]
# #### 第一种方式的例子：

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4, 5]
y = [1, 3, 2, 5, 4, 6]

fig, ax = plt.subplots()
ax.plot(x, y, marker='o')

# 将 x 轴刻度强制设为 [0, 1, 2, 3, 4, 5]
ax.set_xticks([0, 1, 2, 3, 4, 5])

# 将 y 轴添加次刻度 [1.5, 2.5, 3.5, 4.5]
ax.set_yticks([1.5, 2.5, 3.5, 4.5], minor=True)

# 可以配合格式化函数或标签显示
ax.set_yticklabels(['A','B','C','D'], minor=True)

plt.show()
# Out:
# [0 1 2 3 4 5]
# [Text(0, 0, '0'), Text(1, 0, '1'), Text(2, 0, '2'), Text(3, 0, '3'), Text(4, 0, '4'), Text(5, 0, '5')]

# %% [markdown]
# #### 第二种方式的例子

# %% [markdown]
# ##### 例1：maxlocatror 和 multiplelocator 的结合使用

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoLocator, MaxNLocator, MultipleLocator, FixedLocator

fig, ax = plt.subplots()

x = range(11)
y = [i**1.5 for i in x]
ax.plot(x, y, marker='o')

# 1. 自动选取“最佳”主刻度
ax.xaxis.set_major_locator(MultipleLocator(2))

# 2. Y 轴最多 5 条主刻度，数字更整洁
ax.yaxis.set_major_locator(MaxNLocator(5))


# 调整刻度样式
ax.tick_params(which='major', length=8, width=1.2)

plt.show()

# %% [markdown]
# ##### 例2：indexlocator和fixedformatter的例子(用于处理分类数据)

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import IndexLocator, FixedFormatter

# 分类与对应数值
categories = ['A','B','C','D','E']
values     = [10, 20, 15, 25, 18]
x_indices  = list(range(len(categories)))  # 底层位置：0,1,2,3,4

fig, ax = plt.subplots()

# 画折线
ax.plot(x_indices, values, marker='o')

# —— 1) 用 IndexLocator 自动每隔 1 个索引打主刻度 —— #
ax.xaxis.set_major_locator(IndexLocator(base=1, offset=0))

# —— 2) 用 FixedFormatter 把这些刻度映射成分类名 —— #
ax.xaxis.set_major_formatter(FixedFormatter(categories))

# 样式微调
ax.tick_params(which='major', length=6)
ax.set_xlabel('Category')
ax.set_ylabel('Value')
ax.set_title('IndexLocator + FixedFormatter 示例')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\99238\AppData\Local\Temp\ipykernel_3996\1896161019.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.xaxis.set_major_formatter(FixedFormatter(categories))
# C:\Users\99238\AppData\Local\Temp\ipykernel_3996\1896161019.py:26: UserWarning: Glyph 31034 (\N{CJK UNIFIED IDEOGRAPH-793A}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\99238\AppData\Local\Temp\ipykernel_3996\1896161019.py:26: UserWarning: Glyph 20363 (\N{CJK UNIFIED IDEOGRAPH-4F8B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()

# %% [markdown]
# ##### 例3：一个综合使用locator和formatter的例子

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter, MultipleLocator
import numpy as np

# 生成示例数据
x = np.linspace(0, 10, 100)
y = np.sin(x)

# 创建图表
fig, ax = plt.subplots()

ax.plot(x, y)

# 设置 x 轴主刻度为每 2 单位一个
ax.xaxis.set_major_locator(MultipleLocator(2))
# 设置 x 轴次刻度为每 1 单位一个
ax.xaxis.set_minor_locator(MultipleLocator(1))

# 自定义 x 轴标签格式：保留一位小数
ax.xaxis.set_major_formatter(FuncFormatter(lambda val, pos: f"{val:.1f}"))

# 自定义 y 轴标签格式：以百分比显示
ax.yaxis.set_major_formatter(FuncFormatter(lambda val, pos: f"{val*100:.0f}%"))

# 添加标题与网格
ax.set_title("示例: Locator 和 Formatter")
ax.grid(True)

plt.show()
# Out:
# a:\program files\anaconda3\envs\pytorch\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21644 (\N{CJK UNIFIED IDEOGRAPH-548C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ##### matplotlib.ticker.LogLocator(base=10.0, subs=None, numticks=15, *, minor=False)与.logformatter
# - LogLocator参数：
#
# | 参数 | 类型 | 默认值 | 说明 |
# |------|------|--------|------|
# | base | float | 10.0 | 对数的底，例如 10 表示以 10 为底的对数刻度（常用）。 |
# | subs | sequence/None | None | 子刻度的位置（子倍数）就是不同量级之间主刻度的数量，例如 [1.0, 2.0, 5.0] 表示显示 log base 上的这些倍数。若为 None，主刻度将自动生成。 |
# | numticks | int | 15 | 最大刻度数量（是个建议值，不一定严格遵守）。 |
# | minor | bool | False | 是否是用于次刻度（minor ticks）。若为 True，表示这是一个次刻度定位器。 |
#
# - LogFormatter参数：
#
# | 参数 | 类型 | 默认值 | 说明 |
# |------|------|--------|------|
# | base | float | 10.0 | 对数的底，例如 10 表示以 10 为底的对数刻度（常用）。 |
# | labelOnlyBase | bool | False | 是否只在底数的整数次幂处显示标签（如 10^0, 10^1, 10^2）。若为 True，则只显示这些位置的标签。 |
# | minor_thresholds | tuple | (1, 0.4) | 控制次刻度标签显示的阈值。第一个值控制主刻度间隔，第二个值控制次刻度密度。 |
# | linthresh | float | None | 线性阈值，用于对称对数刻度。 |
# - 如果要用科学计数法显示label，则需要使用LogFormatterSciNotation

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import LogLocator,LogFormatter

# 数据
x = np.logspace(0.1, 3, 400)  # x 从 10^0.1 到 10^2，400 个点
y = np.sqrt(x)

# 创建图形
fig, ax = plt.subplots()
ax.plot(x, y)

# 设置对数坐标轴
ax.set_xscale('log')
ax.set_yscale('log')

# 使用 LogLocator 设置主刻度和次刻度
ax.yaxis.set_major_locator(LogLocator(base=10.0, numticks=10,subs=[1.0,2.0,5.0]))
ax.yaxis.set_major_formatter(LogFormatter(labelOnlyBase=False,minor_thresholds=(np.inf,np.inf)))

# 添加网格以更好地观察刻度
# ax.grid(True, which='both', linestyle='--', linewidth=0.5)

ax.set_title("LogLocator 示例")
plt.show()
# Out:
# a:\program files\anaconda3\envs\pytorch\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 31034 (\N{CJK UNIFIED IDEOGRAPH-793A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# a:\program files\anaconda3\envs\pytorch\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20363 (\N{CJK UNIFIED IDEOGRAPH-4F8B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #### ax.tick_params(axis='both', which='major', **kwargs)的用法：

# %%
import matplotlib.pyplot as plt
import numpy as np

# 示例数据
x = np.linspace(0, 10, 100)
y = np.sin(x)

fig, ax = plt.subplots(figsize=(6, 4))
ax.plot(x, y, label='sin(x)')

# 应用 tick_params
# 对主刻度进行设置：字体大小、字体颜色、刻度线长度、线宽、刻度线方向和颜色
ax.tick_params(
    axis='both',       # 设置 x 和 y 轴
    which='major',     # 主要刻度
    labelsize=12,      # 刻度标签字体大小
    labelcolor='blue', # 刻度标签颜色
    length=8,          # 刻度线长度
    width=2,           # 刻度线宽度
    direction='in',    # 刻度线朝内绘制
    colors='red'       # 刻度线颜色
)

# 对次刻度进行设置：开启次刻度并设置长度和颜色
ax.minorticks_on()
ax.tick_params(
    axis='both',
    which='minor',
    length=4,
    colors='green'
)

ax.set_title("示例：ax.tick_params 的使用")
ax.legend(loc='upper left')

plt.show()

## 没安装中文字符，所以会有警告；
# Out:
# a:\program files\anaconda3\envs\pytorch\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 31034 (\N{CJK UNIFIED IDEOGRAPH-793A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# a:\program files\anaconda3\envs\pytorch\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20363 (\N{CJK UNIFIED IDEOGRAPH-4F8B}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# a:\program files\anaconda3\envs\pytorch\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 65306 (\N{FULLWIDTH COLON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# a:\program files\anaconda3\envs\pytorch\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ### color_map相关

# %% [markdown]
# #### Normalization

# %%
import matplotlib as mpl
norm = mpl.colors.Normalize(vmin=-1, vmax=1)
norm(2)
# Out:
# np.float64(1.5)

# %%
import matplotlib.pyplot as plt
import numpy as np

from matplotlib import cm
import matplotlib.cbook as cbook
import matplotlib.colors as colors

N = 100
X, Y = np.mgrid[-3:3:complex(0, N), -2:2:complex(0, N)]

# A low hump with a spike coming out of the top right.  Needs to have
# z/colour axis on a log scale, so we see both hump and spike. A linear
# scale only shows the spike.
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X * 10)**2 - (Y * 10)**2) #高斯函数
Z = Z1 + 50 * Z2

fig, ax = plt.subplots(2, 1)

pcm = ax[0].pcolor(X, Y, Z,
                   norm=colors.LogNorm(vmin=Z.min(), vmax=Z.max()),
                   cmap='PuBu_r', shading='auto')
fig.colorbar(pcm, ax=ax[0], extend='max')

pcm = ax[1].pcolor(X, Y, Z, cmap='PuBu_r', shading='auto')
fig.colorbar(pcm, ax=ax[1], extend='max')
plt.show()

# %% [markdown]
# #### colorbar
# - 一些参数
# mappable: 必填，来自 imshow/pcolor/contourf 等的返回对象（决定 cmap 和 norm）。
# ax / cax: 把 colorbar 放到哪个坐标轴。ax 关联现有子图；cax 直接指定一个专门的轴对象。
# orientation: 'vertical' 或 'horizontal'。
# fraction: colorbar 厚度占参考轴尺寸的比例（默认约 0.15）。
# pad: 图与 colorbar 的间距（相对参考轴的比例）。
# shrink: 沿着长边收缩长度（0–1）。
# aspect: 长边/短边的纵横比（影响“瘦/胖”）。
# ticks: 刻度位置（列表或 Locator）。
# format: 刻度格式（如 '%.2f' 或 Formatter）。
# label: cbar.set_label('...') 设置标题；或使用 cbar.ax.set_title(...)。
# extend: 'neither'|'min'|'max'|'both'，显示越界三角（需与 norm/vmin/vmax 配合）。
# extendfrac / extendrect: 控制越界三角长度或改为矩形延伸。
# boundaries / values: 离散分箱的边界与对应值（配合 BoundaryNorm）。
# spacing: 'uniform' 或 'proportional'（对离散色条生效）。
# use_gridspec: 与 gridspec/布局联动，避免挤压。
# 其他：alpha、drawedges（显示分箱边线）、norm/cmap（仅在用 ColorbarBase 时显式给 出）。

# %% [markdown]
# ## 官网教程

# %% [markdown]
# ### 输入数据的方式
# - numpy
# - 可索引类型并提供关键字参数data

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(19680801)  # seed the random number generator.
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')

# %% [markdown]
# ### 编程风格：
# 1. 显示构建各种artists对象，称为OO(object-oriented)风格；
# 2. 通过plt隐式构建；

# %% [markdown]
# ### Styling artists
# - 有两种方式，一种是在创建时设置，另一种是创建后设置；

# %%
import numpy as np
np.random.seed(1)
data1, data2 = np.random.randn(2,100)
fig, ax = plt.subplots(figsize=(5, 2.7))
x = np.arange(len(data1))
ax.plot(x, np.cumsum(data1), color='blue', linewidth=3, linestyle='--')
l, = ax.plot(x, np.cumsum(data2), color='orange', linewidth=2) #创建后设置要保存引用；
l.set_linestyle(':')

# %% [markdown]
# ### 可以设计的内容：
# - 坐标轴：
#     - 取值范围： ax.set_xlim(0,10)
#     - 尺度： ax.set_xscale('log')
#     - 位置和标签： locator, formatter
#     - 样式: ax.tick_params()
#     - 坐标轴名称： ax.set_xlabel('x-label')
# - 文字：
#     - text
#     - anotation
# - 一图多轴和多图共享轴；
# - colormap:
#     - normalization
#     - 设置color bar
# - 多个图的布局；
